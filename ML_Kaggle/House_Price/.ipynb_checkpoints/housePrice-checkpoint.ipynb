# %%
# Standard import
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\PBANE\\OneDrive - Monsanto\\Migrated from My PC\\Documents\\DataScienceAnalytics\\Python\\Python_Projects\\ML_Kaggle\\House_Price'

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
rawData = pd.read_csv("train.csv")

# %%
housingData = rawData.copy()
housingData.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
housingData.iloc[:3, :5]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea
# 0   1          60       RL         65.0     8450
# 1   2          20       RL         80.0     9600
# 2   3          60       RL         68.0    11250

# %%
housingData.loc[:4, 'MSZoning':'LotArea']
# Out:
#   MSZoning  LotFrontage  LotArea
# 0       RL         65.0     8450
# 1       RL         80.0     9600
# 2       RL         68.0    11250
# 3       RL         60.0     9550
# 4       RL         84.0    14260

# %%
housingData.loc[:10,'Id':'LotArea']
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea
# 0    1          60       RL         65.0     8450
# 1    2          20       RL         80.0     9600
# 2    3          60       RL         68.0    11250
# 3    4          70       RL         60.0     9550
# 4    5          60       RL         84.0    14260
# 5    6          50       RL         85.0    14115
# 6    7          20       RL         75.0    10084
# 7    8          60       RL          NaN    10382
# 8    9          50       RM         51.0     6120
# 9   10         190       RL         50.0     7420
# 10  11          20       RL         70.0    11200

# %%
housingData.loc[2:3, 'LotArea']
# Out:
# 2    11250
# 3     9550
# Name: LotArea, dtype: int64

# %%
housingData.loc[housingData.PoolArea != 0, ['LotArea', 'MSZoning']]
# Out:
#       LotArea MSZoning
# 197     25419       RL
# 810     10140       RL
# 1170     9880       RL
# 1182    15623       RL
# 1298    63887       RL
# 1386    16692       RL
# 1423    19690       RL

# %%
housingData[housingData['LotArea'] == 10140]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 542    543          20       RL         78.0    10140   Pave   NaN      Reg
# 715    716          20       RL         78.0    10140   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1204  1205          20       RL         78.0    10140   Pave   NaN      Reg
# 1293  1294          60       RL         78.0    10140   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 542          Lvl    AllPub    ...            0    NaN    NaN         NaN
# 715          Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 810          Lvl    AllPub    ...          648     Fa  GdPrv         NaN
# 1204         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1293         Lvl    AllPub    ...            0    NaN   GdWo         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 542        0      6   2009        WD         Normal     213250
# 715        0      8   2009        WD         Normal     165000
# 810        0      1   2006        WD         Normal     181000
# 1204       0      7   2006        WD         Normal     153500
# 1293       0      3   2006        WD         Normal     162900
#
# [5 rows x 81 columns]

# %%
housingData.loc[housingData.LotArea == 10140]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 542    543          20       RL         78.0    10140   Pave   NaN      Reg
# 715    716          20       RL         78.0    10140   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1204  1205          20       RL         78.0    10140   Pave   NaN      Reg
# 1293  1294          60       RL         78.0    10140   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 542          Lvl    AllPub    ...            0    NaN    NaN         NaN
# 715          Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 810          Lvl    AllPub    ...          648     Fa  GdPrv         NaN
# 1204         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1293         Lvl    AllPub    ...            0    NaN   GdWo         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 542        0      6   2009        WD         Normal     213250
# 715        0      8   2009        WD         Normal     165000
# 810        0      1   2006        WD         Normal     181000
# 1204       0      7   2006        WD         Normal     153500
# 1293       0      3   2006        WD         Normal     162900
#
# [5 rows x 81 columns]

# %%
housingData.loc[housingData['LotArea'] == 10140, ['MSSubClass', 'MSZoning', 'SalePrice']]
# Out:
#       MSSubClass MSZoning  SalePrice
# 542           20       RL     213250
# 715           20       RL     165000
# 810           20       RL     181000
# 1204          20       RL     153500
# 1293          60       RL     162900

# %%
housingData.loc[housingData['LotArea'] == 10140, ['MSSubClass', 'MSZoning', 'SalePrice']]
# Out:
#       MSSubClass MSZoning  SalePrice
# 542           20       RL     213250
# 715           20       RL     165000
# 810           20       RL     181000
# 1204          20       RL     153500
# 1293          60       RL     162900

# %%
def makeDataFrame(cols, ind):
    data = {c: [str(c) + str(i) for i in ind]
           for c in cols}
    return pd.DataFrame(data, ind)

# %%
makeDataFrame('ABC', range(3))
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
a = housingData.loc[housingData['Id'][:10], ['Id','LotArea', 'SalePrice']]

# %%
b = housingData.loc[housingData['Id'][:10], ['Street', 'MoSold', 'YrSold']]

# %%
pd.concat([a, b], axis= 1)
# Out:
#     Id  LotArea  SalePrice Street  MoSold  YrSold
# 1    2     9600     181500   Pave       5    2007
# 2    3    11250     223500   Pave       9    2008
# 3    4     9550     140000   Pave       2    2006
# 4    5    14260     250000   Pave      12    2008
# 5    6    14115     143000   Pave      10    2009
# 6    7    10084     307000   Pave       8    2007
# 7    8    10382     200000   Pave      11    2009
# 8    9     6120     129900   Pave       4    2008
# 9   10     7420     118000   Pave       1    2008
# 10  11    11200     129500   Pave       2    2008

# %%
pd.concat([a,b], join = 'outer')
# Out:
# C:\Users\PBANE\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       Id  LotArea  MoSold  SalePrice Street  YrSold
# 1    2.0   9600.0     NaN   181500.0    NaN     NaN
# 2    3.0  11250.0     NaN   223500.0    NaN     NaN
# 3    4.0   9550.0     NaN   140000.0    NaN     NaN
# 4    5.0  14260.0     NaN   250000.0    NaN     NaN
# 5    6.0  14115.0     NaN   143000.0    NaN     NaN
# 6    7.0  10084.0     NaN   307000.0    NaN     NaN
# 7    8.0  10382.0     NaN   200000.0    NaN     NaN
# 8    9.0   6120.0     NaN   129900.0    NaN     NaN
# 9   10.0   7420.0     NaN   118000.0    NaN     NaN
# 10  11.0  11200.0     NaN   129500.0    NaN     NaN
# 1    NaN      NaN     5.0        NaN   Pave  2007.0
# 2    NaN      NaN     9.0        NaN   Pave  2008.0
# 3    NaN      NaN     2.0        NaN   Pave  2006.0
# 4    NaN      NaN    12.0        NaN   Pave  2008.0
# 5    NaN      NaN    10.0        NaN   Pave  2009.0
# 6    NaN      NaN     8.0        NaN   Pave  2007.0
# 7    NaN      NaN    11.0        NaN   Pave  2009.0
# 8    NaN      NaN     4.0        NaN   Pave  2008.0
# 9    NaN      NaN     1.0        NaN   Pave  2008.0
# 10   NaN      NaN     2.0        NaN   Pave  2008.0

# %%
housingData.head(4)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
#
# [4 rows x 81 columns]

# %%
housingData.groupby('MSZoning').count()
# Out:
#             Id  MSSubClass  LotFrontage  LotArea  Street  Alley  LotShape  \
# MSZoning
# C (all)     10          10           10       10      10      2        10
# FV          65          65           57       65      65     24        65
# RH          16          16           13       16      16      2        16
# RL        1151        1151          922     1151    1151     20      1151
# RM         218         218          199      218     218     43       218
#
#           LandContour  Utilities  LotConfig    ...      PoolArea  PoolQC  \
# MSZoning                                       ...
# C (all)            10         10         10    ...            10       0
# FV                 65         65         65    ...            65       0
# RH                 16         16         16    ...            16       0
# RL               1151       1151       1151    ...          1151       7
# RM                218        218        218    ...           218       0
#
#           Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  \
# MSZoning
# C (all)       3            2       10      10      10        10
# FV            1            0       65      65      65        65
# RH            2            0       16      16      16        16
# RL          229           45     1151    1151    1151      1151
# RM           46            7      218     218     218       218
#
#           SaleCondition  SalePrice
# MSZoning
# C (all)              10         10
# FV                   65         65
# RH                   16         16
# RL                 1151       1151
# RM                  218        218
#
# [5 rows x 80 columns]

# %%
housingData.groupby('MSZoning')[['SalePrice', 'YrSold']].min()
# Out:
#           SalePrice  YrSold
# MSZoning
# C (all)       34900    2006
# FV           144152    2006
# RH            76000    2006
# RL            39300    2006
# RM            37900    2006

# %%
housingData.groupby('MSZoning')[['SalePrice', 'YrSold']].describe()
# Out:
#          SalePrice                                                    \
#              count           mean           std       min        25%
# MSZoning
# C (all)       10.0   74528.000000  33791.092031   34900.0   43998.25
# FV            65.0  214014.061538  52369.662067  144152.0  174000.00
# RH            16.0  131558.375000  35714.118435   76000.0  106150.00
# RL          1151.0  191004.994787  80766.341319   39300.0  137700.00
# RM           218.0  126316.830275  48521.689833   37900.0  100000.00
#
#                                         YrSold                                 \
#                50%       75%       max   count         mean       std     min
# MSZoning
# C (all)    74700.0   98332.0  133900.0    10.0  2008.300000  1.567021  2006.0
# FV        205950.0  250000.0  370878.0    65.0  2007.846154  1.325599  2006.0
# RH        136500.0  148608.5  200000.0    16.0  2007.500000  1.095445  2006.0
# RL        174000.0  224700.0  755000.0  1151.0  2007.824500  1.333367  2006.0
# RM        120500.0  140000.0  475000.0   218.0  2007.761468  1.308597  2006.0
#
#
#               25%     50%      75%     max
# MSZoning
# C (all)   2007.25  2008.5  2009.75  2010.0
# FV        2007.00  2008.0  2009.00  2010.0
# RH        2007.00  2007.0  2008.25  2009.0
# RL        2007.00  2008.0  2009.00  2010.0
# RM        2007.00  2008.0  2009.00  2010.0

# %%
housingData.groupby('MSZoning')[['SalePrice']].aggregate([np.mean, np.median])
# Out:
#               SalePrice
#                    mean  median
# MSZoning
# C (all)    74528.000000   74700
# FV        214014.061538  205950
# RH        131558.375000  136500
# RL        191004.994787  174000
# RM        126316.830275  120500

# %%
housingData.groupby('MSZoning')[['SalePrice']].aggregate([min, max])
# Out:
#          SalePrice
#                min     max
# MSZoning
# C (all)      34900  133900
# FV          144152  370878
# RH           76000  200000
# RL           39300  755000
# RM           37900  475000

# %%
housingData.groupby('SaleType')[['SalePrice']].aggregate({'meanPrice': 'min'})
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-66-85aa59ed03f3> in <module>
# ----> 1 housingData.groupby('SaleType')[['SalePrice']].aggregate({'meanPrice': 'min'})
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4654         axis=''))
#    4655     def aggregate(self, arg, *args, **kwargs):
# -> 4656         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4657
#    4658     agg = aggregate
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4085
#    4086         _level = kwargs.pop('_level', None)
# -> 4087         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    4088         if how is None:
#    4089             return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     471                 if len(sl) == 1:
#     472
# --> 473                     result = _agg(arg, lambda fname,
#     474                                   agg_how: _agg_1dim(self._selection, agg_how))
#     475
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     439                 result = compat.OrderedDict()
#     440                 for fname, agg_how in compat.iteritems(arg):
# --> 441                     result[fname] = func(fname, agg_how)
#     442                 return result
#     443
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in <lambda>(fname, agg_how)
#     472
#     473                     result = _agg(arg, lambda fname,
# --> 474                                   agg_how: _agg_1dim(self._selection, agg_how))
#     475
#     476                 # we are selecting the same set as we are aggregating
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     420                 colg = self._gotitem(name, ndim=1, subset=subset)
#     421                 if colg.ndim != 1:
# --> 422                     raise SpecificationError("nested dictionary is ambiguous "
#     423                                              "in aggregation")
#     424                 return colg.aggregate(how, _level=(_level or 0) + 1)
#
# SpecificationError: nested dictionary is ambiguous in aggregation
